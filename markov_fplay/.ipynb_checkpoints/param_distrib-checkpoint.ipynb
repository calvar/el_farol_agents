# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = [
    pd.read_table("simulation_params_N4.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy']),
    pd.read_table("simulation_params_N4C001a1.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy']),
    pd.read_table("simulation_params_N4C005a1.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy']),
    pd.read_table("simulation_params_N4C01a1.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy']),
    pd.read_table("simulation_params_N4C05a1.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy']),
]

# %%
for d in df:
    d['efficiency'].describe()

# %%
nr = 5
nc = 2
fig0, ax = plt.subplots(nrows=nr,ncols=nc,figsize=(5,6))
for i in range(len(df)):
    pa = sns.histplot(data=df[i], ax=ax[i,0], x='efficiency', binwidth=10)
    pb = sns.histplot(data=df[i], ax=ax[i,1], x='inequality', binwidth=10)
    pa.set_xlim(0,250)
    pa.set_ylim(0,250)
    pb.set_xlim(0,250)
    pb.set_ylim(0,250)
plt.tight_layout()

# %%
#fig0, ax = plt.subplots(nrows=3,ncols=1,figsize=(1,1),tight_layout=True)
sns.displot(data=df1, x="efficiency", y="inequality", kind="hist")
sns.displot(data=df2, x="efficiency", y="inequality", kind="hist")
sns.displot(data=df3, x="efficiency", y="inequality", kind="hist")
sns.displot(data=df4, x="efficiency", y="inequality", kind="hist")

# %%
from pathlib import Path 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %%
folder = Path('./params')
for f in folder.iterdir():
    print(f.name.split('C')[-1].rstrip('.dat'))
# Out:
# 0.3
# 0.05
# 0.0
# 0.1
# 1.0
# 0.01
# 0.08
# 0.5
# 0.7

# %%
C_list = []
percent_seg = []
percent_alt = []
eff = []
ineq = []
for f in folder.iterdir():
    C = f.name.split('C')[-1].rstrip('.dat')
    df = pd.read_table(f, sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope','emax_perc'])
    C_list.append(C)
    
    mx = df['inequality'].max()
    mn = 0.95*mx
    df_seg = df[(df['inequality']>mn) & (df['emax_perc']>0.95)]
    percent_seg.append(df_seg.shape[0]/df.shape[0])

    mn = 0.05*mx
    df_alt = df[(df['inequality']<mn) & (df['emax_perc']>0.95)]
    percent_alt.append(df_alt.shape[0]/df.shape[0])

    eff.append(df['efficiency'].mean())
    ineq.append(df['inequality'].mean())

df_c = pd.DataFrame({'c':C_list, '%seg':percent_seg, '%alt':percent_alt, 'eff':eff, 'ineq':ineq})
df_c.c.astype('float')
df_c.sort_values(by='c',inplace=True)
df_c.head()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_6600/3774445529.py:8: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_table(f, sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope','emax_perc'])
#       c      %seg      %alt         eff        ineq
# 2   0.0  0.118136  0.004992  144.911205  129.765882
# 5  0.01  0.051581  0.041597  260.551444  116.685844
# 1  0.05  0.034942  0.079867  276.230712  106.710998
# 6  0.08  0.019967  0.104825  280.799558   98.293343
# 3   0.1  0.041597  0.106489  282.494486   99.532071

# %%
df_c['c'].iloc[df_c['eff'].argmax()]
# Out:
# '0.1'

# %%
sns.lineplot(x='c',y='%seg',data=df_c)
sns.lineplot(x='c',y='%alt',data=df_c)
# Out:
# <Axes: xlabel='c', ylabel='%seg'>

# %%
sns.lineplot(x='c',y='eff',data=df_c)
sns.lineplot(x='c',y='ineq',data=df_c)
# Out:
# <Axes: xlabel='c', ylabel='eff'>

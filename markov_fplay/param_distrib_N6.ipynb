# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfucb = [
    pd.read_table("simulation_params_N6.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope']),
    pd.read_table("simulation_params_N6C001a1_ucb.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope']),
    pd.read_table("simulation_params_N6C005a1_ucb.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope']),
    pd.read_table("simulation_params_N6C01a1_ucb.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope']),
    
    pd.read_table("simulation_params_N6C03a1_ucb.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope']),
    pd.read_table("simulation_params_N6C05a1_ucb.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope']),
    pd.read_table("simulation_params_N6C1a1_ucb.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope']),
]

# %%
dfucb[1]
# Out:
#      efficiency  inequality  n_efficiency  n_inequality   entropy  frequency  \
# 0    255.327056   67.139904      0.118757      0.031153  0.059493   1.000000
# 1    187.608389   69.890900      0.108941      0.040638  0.728359   0.125000
# 2    302.420000  173.861116      0.083574      0.048047  0.194143   0.500000
# 3    243.976778   70.379140      0.113458      0.032737  0.543487   0.111111
# 4    201.611111   88.717895      0.093350      0.041070  0.166667   0.500000
# ..          ...         ...           ...           ...       ...        ...
# 596  239.013889   55.947623      0.131741      0.030469  0.000000   1.000000
# 597  240.125000   58.315878      0.125600      0.030355  0.264159   0.333333
# 598  236.930556   69.800958      0.116715      0.034425  0.264159   0.333333
# 599  301.210278  168.502389      0.085195      0.047666  0.279363   0.500000
# 600  265.019444  149.258010      0.089910      0.050637  0.386988   0.200000
#
#      info_per_agent  int_entropy  ineq_slope
# ...

# %%
#for d in df:
#    d['efficiency'].describe()

# %%
nr = len(dfucb)
nc = 2
fig0, ax = plt.subplots(nrows=nr,ncols=nc,figsize=(5,10))
for i in range(len(dfucb)):
    pa = sns.histplot(data=dfucb[i], ax=ax[i,0], x='efficiency', binwidth=10)
    pb = sns.histplot(data=dfucb[i], ax=ax[i,1], x='inequality', binwidth=10)
    pa.set_xlim(0,500)
    pa.set_ylim(0,200)
    pb.set_xlim(0,500)
    pb.set_ylim(0,200)
plt.tight_layout()

# %%
cvals = [0,0.01,0.05,0.1,0.3,0.5,1.0] 
eff_means = [d.efficiency.mean() for d in dfucb]
inq_means = [d.inequality.mean() for d in dfucb]
plt.plot(cvals,eff_means)
plt.plot(cvals,inq_means)

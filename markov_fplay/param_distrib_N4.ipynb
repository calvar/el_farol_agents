# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# df = [
#     pd.read_table("simulation_params_N4.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy']),
#     pd.read_table("simulation_params_N4C001a1.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy']),
#     pd.read_table("simulation_params_N4C003a1.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy']),
#     pd.read_table("simulation_params_N4C005a1.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy']),
#     pd.read_table("simulation_params_N4C01a1.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy']),
#     pd.read_table("simulation_params_N4C05a1.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy']),
# ]

dfucb = [
    pd.read_table("simulation_params_N4.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope']),
    pd.read_table("simulation_params_N4C001a1_ucb.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope']),
    pd.read_table("simulation_params_N4C005a1_ucb.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope']),
    pd.read_table("simulation_params_N4C008a1_ucb.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope']),
    pd.read_table("simulation_params_N4C01a1_ucb.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope']),
    pd.read_table("simulation_params_N4C03a1_ucb.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope']),
    pd.read_table("simulation_params_N4C05a1_ucb.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope']),
    pd.read_table("simulation_params_N4C07a1_ucb.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope']),
    pd.read_table("simulation_params_N4C1a1_ucb.dat", sep="\s+", header=None, names=['efficiency','inequality','n_efficiency','n_inequality','entropy','frequency','info_per_agent','int_entropy','ineq_slope']),
]

# %%
dfucb[1]
# Out:
#      efficiency  inequality  n_efficiency  n_inequality   entropy  frequency  \
# 0    295.000000   68.872317      0.205200      0.047737  0.000000   1.000000
# 1    437.125000  147.519699      0.183351      0.061878  0.396239   0.333333
# 2    349.750000   87.139326      0.196552      0.048941  0.396239   0.333333
# 3    432.225375   52.498238      0.222345      0.026930  0.478344   0.333333
# 4    376.750000   26.949056      0.222517      0.015949  0.500000   0.250000
# ..          ...         ...           ...           ...       ...        ...
# 596  371.462125  135.715799      0.154518      0.056454  0.014606   0.500000
# 597  444.417500  437.965108      0.125517      0.123692  0.045592   1.000000
# 598  324.302500   81.572455      0.192858      0.048567  0.554558   0.333333
# 599  309.333250    0.909354      0.248758      0.000732  0.396239   0.333333
# 600  349.687500   81.763698      0.186605      0.043719  0.250000   0.500000
#
#      info_per_agent  int_entropy  ineq_slope
# ...

# %%
#for d in df:
#    d['efficiency'].describe()

# %%
# nr = 6
# nc = 2
# fig0, ax = plt.subplots(nrows=nr,ncols=nc,figsize=(5,6))
# for i in range(len(df)):
#     pa = sns.histplot(data=df[i], ax=ax[i,0], x='efficiency', binwidth=10)
#     pb = sns.histplot(data=df[i], ax=ax[i,1], x='inequality', binwidth=10)
#     pa.set_xlim(0,250)
#     pa.set_ylim(0,300)
#     pb.set_xlim(0,250)
#     pb.set_ylim(0,300)
# plt.tight_layout()

# %%
##fig0, ax = plt.subplots(nrows=3,ncols=1,figsize=(1,1),tight_layout=True)
#sns.displot(data=df1, x="efficiency", y="inequality", kind="hist")
#sns.displot(data=df2, x="efficiency", y="inequality", kind="hist")
#sns.displot(data=df3, x="efficiency", y="inequality", kind="hist")
#sns.displot(data=df4, x="efficiency", y="inequality", kind="hist")

# %%
nr = len(dfucb)
nc = 2
fig0, ax = plt.subplots(nrows=nr,ncols=nc,figsize=(5,10))
for i in range(len(dfucb)):
    pa = sns.histplot(data=dfucb[i], ax=ax[i,0], x='efficiency', binwidth=10)
    pb = sns.histplot(data=dfucb[i], ax=ax[i,1], x='inequality', binwidth=10)
    pa.set_xlim(0,500)
    pa.set_ylim(0,200)
    pb.set_xlim(0,500)
    pb.set_ylim(0,200)
plt.tight_layout()

# %%
cvals = [0,0.01,0.05,0.08,0.1,0.3,0.5,0.7,1.0] 
eff_means = [d.efficiency.mean() for d in dfucb]
inq_means = [d.inequality.mean() for d in dfucb]
plt.plot(cvals,eff_means)
plt.plot(cvals,inq_means)
